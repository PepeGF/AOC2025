# %%
import requests
from dotenv import load_dotenv
import os

load_dotenv()
AOC_SESSION = os.getenv("session")

url = "https://adventofcode.com/2025/day/1/input"
s = requests.Session()
s.cookies.set("session", AOC_SESSION)
response = s.get(url)
data = response.text

# %%
lines = data.splitlines()

# %%
inicio = 50
contador_ceros = 0

# %%
for line in lines:
    sentido = 1 if line[0] == "R" else -1
    pasos = int(line[1:]) % 100
    posicion = (inicio + sentido * pasos) % 100
    print(posicion)
    if posicion == 0:
        contador_ceros += 1
    inicio = posicion

# %%
contador_ceros

# %%
posicion = 50
contador_pasos_0 = 0
with open("pasos.txt2", "w") as f:
    for line in lines:
        sentido = 1 if line[0] == "R" else -1
        pasos = int(line[1:])
        # contador_pasos_0 += pasos // 100
        # pasos = pasos % 100
        posicion += sentido * pasos
        temp_posicion = posicion
        if posicion < 0 or posicion > 99:
            # contador_pasos_0 += 1
            posicion = posicion % 100
        f.write(line + (10-len(line)) * " " + str(posicion) + (15-len(str(posicion))-len(line)) * " " + str(temp_posicion) + "\n")

# %%
contador_pasos_0
